# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Life Expectancy Data.csv') # Loading dataset

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.nunique()
# Out:
# Country                             193
# Year                                 16
# Status                                2
# Life expectancy                     362
# Adult Mortality                     425
# infant deaths                       209
# Alcohol                            1076
# percentage expenditure             2328
# Hepatitis B                          87
# Measles                             958
#  BMI                                608
# under-five deaths                   252
# Polio                                73
# Total expenditure                   818
# Diphtheria                           81
#  HIV/AIDS                           200
# GDP                                2490
# Population                         2278
#  thinness  1-19 years               200
#  thinness 5-9 years                 207
# Income composition of resources     625
# Schooling                           173
# dtype: int64

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.sample(10)
# Out:
#                                Country  Year      Status  Life expectancy   \
# 1490                           Liberia  2015  Developing              61.4
# 2424                       South Sudan  2000  Developing              48.9
# 2602                       Timor-Leste  2014  Developing              68.0
# 39                             Algeria  2008  Developing              74.1
# 1711  Micronesia (Federated States of)  2003  Developing              67.5
# 78                 Antigua and Barbuda  2001  Developing              73.8
# 1832                       Netherlands  2012   Developed              81.1
# 166                            Bahamas  2009  Developing              74.6
# 1558                        Madagascar  2011  Developing              63.8
# 1052                           Grenada  2005  Developing              71.5
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 1490            259.0              8      NaN                0.000000
# ...

# %%
# Importing libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.hist(figsize=(14,14))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Life expectancy '] = df['Life expectancy '].fillna(df['Life expectancy '].mean())
df['Adult Mortality']=df['Adult Mortality'].fillna(df['Adult Mortality'].median())
df['Alcohol']=df['Alcohol'].fillna(df['Alcohol'].median())
df['Hepatitis B']=df['Hepatitis B'].fillna(df['Hepatitis B'].mean())
df[' BMI ']=df[' BMI '].fillna(df[' BMI '].mean())
df['Polio']=df['Polio'].fillna(df['Polio'].mean())
df['Diphtheria ']=df['Diphtheria '].fillna(df['Diphtheria '].mean())
df['GDP']=df['GDP'].fillna(df['GDP'].median())
df['Population']=df['Population'].fillna(df['Population'].median())
df['Schooling']=df['Schooling'].fillna(df['Schooling'].mean())
df[' thinness 5-9 years'] = df[' thinness 5-9 years'].fillna(df[' thinness 5-9 years'].median())
df.drop(columns=['Measles '], inplace=True)
df.drop(columns=['Total expenditure'], inplace=True)
df.drop(columns=['Income composition of resources'], inplace=True)

# %%
df.hist(figsize=(14,14))
plt.show()

# %%
df.shape
# Out:
# (2938, 19)

# %%
df.isnull().sum()
# Out:
# Country                    0
# Year                       0
# Status                     0
# Life expectancy            0
# Adult Mortality            0
# infant deaths              0
# Alcohol                    0
# percentage expenditure     0
# Hepatitis B                0
#  BMI                       0
# under-five deaths          0
# Polio                      0
# Diphtheria                 0
#  HIV/AIDS                  0
# GDP                        0
# Population                 0
#  thinness  1-19 years     34
#  thinness 5-9 years        0
# Schooling                  0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                   0
# Year                      0
# Status                    0
# Life expectancy           0
# Adult Mortality           0
# infant deaths             0
# Alcohol                   0
# percentage expenditure    0
# Hepatitis B               0
#  BMI                      0
# under-five deaths         0
# Polio                     0
# Diphtheria                0
#  HIV/AIDS                 0
# GDP                       0
# Population                0
#  thinness  1-19 years     0
#  thinness 5-9 years       0
# Schooling                 0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2904.000000       2904.000000      2904.000000    2904.000000
# mean   2007.515152         69.350275       163.323003      30.149793
# std       4.613230          9.474882       123.720359     118.584321
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.500000        73.000000       0.000000
# 50%    2008.000000         72.200000       143.000000       3.000000
# 75%    2012.000000         75.700000       225.000000      21.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B         BMI   \
# count  2904.000000             2904.000000  2904.000000  2904.000000
# mean      4.570591              746.311045    80.988039    38.321247
# std       3.935893             1998.101290    22.620569    20.044034
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Checking categorical variables
df[['Year', 'Status', 'Country']].nunique()
# Out:
# Year        16
# Status       2
# Country    189
# dtype: int64

# %%
#Checking the status of countries
df.groupby('Status')['Country'].nunique().reset_index()
# Out:
#        Status  Country
# 0   Developed       32
# 1  Developing      157

# %%
corr = df.iloc[:, df.columns!='Year'].corr(numeric_only=True)

# %%
# Making heat map of the various columns 
plt.figure(figsize=(14,10))
plt.title('Heatmap between features')
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# *We see that polio and Diphtheria are highly correlated and one can explain other , there we dont need to keep both. We wil keep Diphtheria
#
# *Similarly we keep thinness 1-19 over thinness 5-9
#
# *We remove under 5 death and keep infant death
#
# *We remove percentage expenditure and keep GDP

# %%
df.drop(columns=['Polio', ' thinness 5-9 years', 'under-five deaths ', 'percentage expenditure'], inplace=True)

# %%
df.shape
# Out:
# (2904, 15)

# %%
ax = sns.kdeplot(data=df, x='Life expectancy ', hue='Status', fill=True,)
ax.set_title("Density of Life Expectancy vs Development status")
# Out:
# Text(0.5, 1.0, 'Density of Life Expectancy vs Development status')

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'Hepatitis B', ' BMI ', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years', 'Schooling'],
#       dtype='object')

# %%
sns.scatterplot(data=df, x='Adult Mortality', y='Life expectancy ')
plt.title('Life expectancy vs Adult mortality')
# Out:
# Text(0.5, 1.0, 'Life expectancy vs Adult mortality')

# %% [raw]
# As Adult mortality increases the life expectancy decreases

# %%
sns.boxplot(data=df, hue='Status', y='Life expectancy ', palette='bright')
plt.title('Life expectancy variation over development')
# Out:
# Text(0.5, 1.0, 'Life expectancy variation over development')

# %% [raw]
# Developed countries have higher life expectancy overall

# %%
ax=sns.relplot(data=df, x='Year', y='Life expectancy ', col='Status', kind='line', hue='Status')
#ax=sns.lineplot(data=df[df['Status']=='Developing'], x='Year', y='Life expectancy ', color='red')

# %% [raw]
# The life expectancy increases with time in both developed and developing countries

# %%
ax=sns.relplot(df, x='GDP', y='Life expectancy ', col='Status', kind='scatter',hue='Status')

# %% [raw]
# This graph tells us about the life expectancy with respect to GDP of developed and develpo

# %%
ax=sns.relplot(df, x='GDP', y='Adult Mortality', col='Status', kind='scatter', hue='Status')

# %%
ax=sns.relplot(df, x='Diphtheria ', y='Life expectancy ', col='Status', kind='line', hue='Status')

# %%
ax=sns.relplot(df, x=' BMI ', y='Life expectancy ', kind='scatter', hue='Status')
plt.title('Life_expectancy vs BMI')
# Out:
# Text(0.5, 1.0, 'Life_expectancy vs BMI')

# %%
ax=sns.relplot(df, x=' thinness  1-19 years', y='Life expectancy ', kind='scatter', hue='Status')
plt.title('Life_expectancy vs thinness')
# Out:
# Text(0.5, 1.0, 'Life_expectancy vs thinness')

# %%
ax=sns.relplot(df, x='Schooling', y='Life expectancy ', kind='scatter', hue='Status')
plt.title('Life_expectancy vs schooling')
# Out:
# Text(0.5, 1.0, 'Life_expectancy vs schooling')

# %%
ax=sns.relplot(df, x='Alcohol', y='Life expectancy ', kind='scatter', hue='Status')
plt.title('Life_expectancy vs Alcohol')
# Out:
# Text(0.5, 1.0, 'Life_expectancy vs Alcohol')

# %%
ax=sns.relplot(df, x='infant deaths', y='Life expectancy ', kind='scatter', hue='Status')
plt.title('Life_expectancy vs infant death')
# Out:
# Text(0.5, 1.0, 'Life_expectancy vs infant death')

# %%
plt.figure(figsize=(20,6))

plt.subplot(131)
sns.kdeplot(data=df, x='GDP', fill=True, hue='Status')
plt.title('GDP pdf')

plt.subplot(132)
sns.kdeplot(data=df, x='Adult Mortality', fill=True, hue='Status')
plt.title('Adult mortality pdf')

plt.subplot(133)
sns.kdeplot(data=df, x='Schooling', fill=True, hue='Status')
plt.title('Schooling pdf')
plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
sns.kdeplot(data=df, x='Hepatitis B', fill=True, hue='Status')
plt.title('Hepatitis B pdf')

plt.subplot(132)
sns.kdeplot(data=df, x='Diphtheria ', fill=True, hue='Status')
plt.title('Diphtheria pdf')

plt.subplot(133)
sns.kdeplot(data=df, x=' thinness  1-19 years', fill=True, hue='Status')
plt.title('Thinness pdf')

plt.show()

# %%
plt.figure(figsize=(20,6))

plt.subplot(131)
sns.kdeplot(data=df, x='Alcohol', fill=True, hue='Status')
plt.title('Alcohol pdf')

plt.subplot(132)
sns.kdeplot(data=df, x=' BMI ', fill=True, hue='Status')
plt.title('BMI pdf')

plt.subplot(133)
sns.kdeplot(data=df, x='Population', fill=True, hue='Status')
plt.title('Population pdf')
plt.show()

# %% [raw]
# From the preliminary analysis based on data exploration and visualization we can come across following conclusions:
#
# *Hepatitis B and Diphtheria have negatively skewed distributions for both developed and developing nations
# *People in developed countries have higher life expecrancy than developed countries
# *Schooling significantly effects life expectancy and so does Adult Mortality
# *People in developed countries have more alcohol on an average.

# %% [markdown]
# ### Preprocessing

# %%
from sklearn.model_selection import train_test_split

# %%
ohe=pd.get_dummies(data=df, columns=['Status'])

# %%
ohe.head()
# Out:
#        Country  Year  Life expectancy   Adult Mortality  infant deaths  \
# 0  Afghanistan  2015              65.0            263.0             62
# 1  Afghanistan  2014              59.9            271.0             64
# 2  Afghanistan  2013              59.9            268.0             66
# 3  Afghanistan  2012              59.5            272.0             69
# 4  Afghanistan  2011              59.2            275.0             71
#
#    Alcohol  Hepatitis B   BMI   Diphtheria    HIV/AIDS         GDP  \
# 0     0.01         65.0   19.1         65.0        0.1  584.259210
# 1     0.01         62.0   18.6         62.0        0.1  612.696514
# 2     0.01         64.0   18.1         64.0        0.1  631.744976
# 3     0.01         67.0   17.6         67.0        0.1  669.959000
# 4     0.01         68.0   17.2         68.0        0.1   63.537231
#
#    Population   thinness  1-19 years  Schooling  Status_Developed  \
# ...

# %%
df_new = ohe.drop(columns=['Country', 'Year'])

# %%
# Separating the target column from the data
X = df_new.drop('Life expectancy ', axis=1)
y = df_new['Life expectancy ']

# %%
X.columns
# Out:
# Index(['Adult Mortality', 'infant deaths', 'Alcohol', 'Hepatitis B', ' BMI ',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', 'Schooling', 'Status_Developed',
#        'Status_Developing'],
#       dtype='object')

# %%
y.shape
# Out:
# (2904,)

# %%
# Doing train test split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=4)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
# Creating holders to store the model performance results
ML_Model = []
R2_train = []
R2_test = []
MSE_train = []
MSE_test = []

#function to call for storing the results
def storeResults(model, a,b,c,d):
  ML_Model.append(model)
  R2_train.append(round(a, 3))
  R2_test.append(round(b, 3))
  MSE_train.append(round(c,3)) 
  MSE_test.append(round(d,3))

# %% [markdown]
# ### Linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
# Removing insignificant feature
X_train.drop(columns=['Population'], inplace=True)

# %%
X_test.drop(columns = ['Population'], inplace=True)

# %%
X_train.columns
# Out:
# Index(['Adult Mortality', 'infant deaths', 'Alcohol', 'Hepatitis B', ' BMI ',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', ' thinness  1-19 years', 'Schooling',
#        'Status_Developed', 'Status_Developing'],
#       dtype='object')

# %%
y_train.shape
# Out:
# (2323,)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_lr = lr.predict(X_train)
y_test_lr = lr.predict(X_test)

# %% [raw]
# Performance

# %%
R2_train_lr = r2_score(y_train, y_train_lr)
R2_test_lr = r2_score(y_test, y_test_lr)
MSE_train_lr = mean_squared_error(y_train, y_train_lr)
MSE_test_lr = mean_squared_error(y_test, y_test_lr)

# %%
print("Linear regression: R2 score on training Data: {:.3f}".format(R2_train_lr))
print("Linear regression: R2 score on test Data: {:.3f}".format(R2_test_lr))
print("Linear regression: MSE on training Data: {:.3f}".format(MSE_train_lr))
print("Linear regression: MSE on test Data: {:.3f}".format(MSE_test_lr))
# Out:
# Linear regression: R2 score on training Data: 0.802
# Linear regression: R2 score on test Data: 0.771
# Linear regression: MSE on training Data: 18.277
# Linear regression: MSE on test Data: 18.101

# %%
# Storing results
storeResults('Linear regression', R2_train_lr, R2_test_lr,MSE_train_lr,MSE_test_lr)

# %% [markdown]
# ### Polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2)

# %%
# Introducing polynomial features
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
lr1 = LinearRegression()
lr1.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
y_train_poly = lr1.predict(X_train_poly)
y_test_poly = lr1.predict(X_test_poly)

# %% [raw]
# Performance

# %%
R2_train_poly = r2_score(y_train, y_train_poly)
R2_test_poly = r2_score(y_test, y_test_poly)
MSE_train_poly = mean_squared_error(y_train, y_train_poly)
MSE_test_poly = mean_squared_error(y_test, y_test_poly)

# %%
print("Polynomial regression: R2 score on training Data: {:.3f}".format(R2_train_poly))
print("Polynomial regression: R2 score on test Data: {:.3f}".format(R2_test_poly))
print("Polynomial regression: MSE on training Data: {:.3f}".format(MSE_train_poly))
print("Polynomial regression: MSE on test Data: {:.3f}".format(MSE_test_poly))
# Out:
# Polynomial regression: R2 score on training Data: 0.899
# Polynomial regression: R2 score on test Data: 0.862
# Polynomial regression: MSE on training Data: 9.325
# Polynomial regression: MSE on test Data: 10.857

# %% [raw]
# Storing results

# %%
storeResults('Polynomial regression', R2_train_poly, R2_test_poly, MSE_train_poly, MSE_test_poly)

# %% [markdown]
# ### Lasso regression

# %%
from sklearn.linear_model import Lasso

# %%
las = Lasso(alpha=0.001, max_iter=500)
las.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001, max_iter=500)

# %%
y_train_las = las.predict(X_train)
y_test_las = las.predict(X_test)

# %% [raw]
# Performance

# %%
R2_train_las = r2_score(y_train, y_train_las)
R2_test_las = r2_score(y_test, y_test_las)
MSE_train_las = mean_squared_error(y_train, y_train_las)
MSE_test_las = mean_squared_error(y_test, y_test_las)

# %%
print("Lasso regression: R2 score on training Data: {:.3f}".format(R2_train_las))
print("Lasso regression: R2 score on test Data: {:.3f}".format(R2_test_las))
print("Lasso regression: MSE on training Data: {:.3f}".format(MSE_train_las))
print("Lasso regression: MSE on test Data: {:.3f}".format(MSE_test_las))
# Out:
# Lasso regression: R2 score on training Data: 0.802
# Lasso regression: R2 score on test Data: 0.771
# Lasso regression: MSE on training Data: 18.277
# Lasso regression: MSE on test Data: 18.102

# %%
# Record results
storeResults('Lasso regression', R2_train_las, R2_test_las, MSE_train_las, MSE_test_las)

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'max_depth': [2,4,8,10],
    'max_features': [0.2,0.4,0.75,1.0],
    'min_samples_split': [2,5,10,15,20,25],
    'min_samples_leaf': [2,6,10,15],
    'criterion': ['squared_error', 'absolute_error']
}

# %%
search = GridSearchCV(estimator=DecisionTreeRegressor(), param_grid=param_grid, cv=10, n_jobs=-1, verbose=1, scoring='r2')
search.fit(X_train, y_train)

print('Best features:', search.best_params_)
# Out:
# Fitting 10 folds for each of 768 candidates, totalling 7680 fits
# Best features: {'criterion': 'squared_error', 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 6, 'min_samples_split': 2}

# %%
dt = search.best_estimator_

# %%
# Finding predicted values
y_train_dt = dt.predict(X_train)
y_test_dt = dt.predict(X_test)

# %% [raw]
# Performance

# %%
R2_train_dt = r2_score(y_train, y_train_dt)
R2_test_dt = r2_score(y_test, y_test_dt)
MSE_train_dt = mean_squared_error(y_train, y_train_dt)
MSE_test_dt = mean_squared_error(y_test, y_test_dt)

# %%
print("Decision Tree regression: R2 score on training Data: {:.3f}".format(R2_train_dt))
print("Decision Tree regression: R2 score on test Data: {:.3f}".format(R2_test_dt))
print("Decision Tree regression: MSE on training Data: {:.3f}".format(MSE_train_dt))
print("Decision Tree regression: MSE on test Data: {:.3f}".format(MSE_test_dt))
# Out:
# Decision Tree regression: R2 score on training Data: 0.969
# Decision Tree regression: R2 score on test Data: 0.931
# Decision Tree regression: MSE on training Data: 2.860
# Decision Tree regression: MSE on test Data: 5.429

# %%
# Store results
storeResults('Decision tree regressor', R2_train_dt, R2_test_dt, MSE_train_dt, MSE_test_dt)

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_scores = cross_val_score(dt, X, y, cv=10, scoring='r2')
print(f"Mean R2: {cv_scores.mean():.4f}")
print(f"Std Dev: {cv_scores.std():.4f}")
# Out:
# Mean R2: 0.8654
# Std Dev: 0.0447

# %% [markdown]
# ### SVR

# %%
from sklearn.pipeline import Pipeline
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# %%
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('svr', SVR(kernel='rbf'))
])

param_grid = {

    'svr__degree': [2,3],
    'svr__gamma': ['auto', 'scale'],
    'svr__epsilon': [0.1,0.5,1.0],
    'svr__C': [1000,10000]
}

search1 = GridSearchCV(estimator=pipe, param_grid=param_grid, cv=5, n_jobs=-1, verbose=1, scoring='r2')

search1.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('svr', SVR())]),
#              n_jobs=-1,
#              param_grid={'svr__C': [1000, 10000], 'svr__degree': [2, 3],
#                          'svr__epsilon': [0.1, 0.5, 1.0],
#                          'svr__gamma': ['auto', 'scale']},
#              scoring='r2', verbose=1)

# %%
print('Best features:', search1.best_params_)
# Out:
# Best features: {'svr__C': 1000, 'svr__degree': 2, 'svr__epsilon': 1.0, 'svr__gamma': 'auto'}

# %%
svr = search1.best_estimator_

# %%
# Finding predicted values
y_train_svr = svr.predict(X_train)
y_test_svr = svr.predict(X_test)

# %% [raw]
# Performance

# %%
R2_train_svr = r2_score(y_train, y_train_svr)
R2_test_svr = r2_score(y_test, y_test_svr)
MSE_train_svr = mean_squared_error(y_train, y_train_svr)
MSE_test_svr = mean_squared_error(y_test, y_test_svr)

# %%
print("SVR regression: R2 score on training Data: {:.3f}".format(R2_train_svr))
print("SVR regression: R2 score on test Data: {:.3f}".format(R2_test_svr))
print("SVR regression: MSE on training Data: {:.3f}".format(MSE_train_svr))
print("SVR regression: MSE on test Data: {:.3f}".format(MSE_test_svr))
# Out:
# SVR regression: R2 score on training Data: 0.970
# SVR regression: R2 score on test Data: 0.916
# SVR regression: MSE on training Data: 2.782
# SVR regression: MSE on test Data: 6.637

# %%
storeResults('SVR', R2_train_svr, R2_test_svr, MSE_train_svr, MSE_test_svr)

# %%
cv_scores = cross_val_score(svr, X, y, cv=10, scoring='r2')
print(f"Mean R2: {cv_scores.mean():.4f}")
print(f"Std Dev: {cv_scores.std():.4f}")
# Out:
# Mean R2: 0.8574
# Std Dev: 0.0241

# %% [markdown]
# ### Random forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=500, max_depth=20, min_samples_split=20, min_samples_leaf=5, n_jobs=-1)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=20, min_samples_leaf=5, min_samples_split=20,
#                       n_estimators=500, n_jobs=-1)

# %%
# Finding predicted values
y_train_rf = rf.predict(X_train)
y_test_rf = rf.predict(X_test)

# %%
R2_train_rf = r2_score(y_train, y_train_rf)
R2_test_rf = r2_score(y_test, y_test_rf)
MSE_train_rf = mean_squared_error(y_train, y_train_rf)
MSE_test_rf = mean_squared_error(y_test, y_test_rf)

# %%
print("Random forest regression: R2 score on training Data: {:.3f}".format(R2_train_rf))
print("Random forest regression: R2 score on test Data: {:.3f}".format(R2_test_rf))
print("Random forest regression: MSE on training Data: {:.3f}".format(MSE_train_rf))
print("Random forest regression: MSE on test Data: {:.3f}".format(MSE_test_rf))
# Out:
# Random forest regression: R2 score on training Data: 0.972
# Random forest regression: R2 score on test Data: 0.952
# Random forest regression: MSE on training Data: 2.607
# Random forest regression: MSE on test Data: 3.823

# %%
cv_scores = cross_val_score(rf, X, y, cv=10, scoring='r2')
print(f"Mean R2: {cv_scores.mean():.4f}")
print(f"Std Dev: {cv_scores.std():.4f}")
# Out:
# Mean R2: 0.9064
# Std Dev: 0.0295

# %%
storeResults('Random forest', R2_train_rf, R2_test_rf, MSE_train_rf, MSE_test_rf)

# %% [markdown]
# # Model comparison

# %%
# Create a dataframe

results = pd.DataFrame({
    'ML_model': ML_Model,
    'R2_train': R2_train,
    'R2_test': R2_test,
    'MSE_train': MSE_train,
    'MSE_test': MSE_test
})

# %%
results
# Out:
#                   ML_model  R2_train  R2_test  MSE_train  MSE_test
# 0        Linear regression     0.802    0.771     18.277    18.101
# 1    Polynomial regression     0.899    0.862      9.325    10.857
# 2         Lasso regression     0.802    0.771     18.277    18.102
# 3  Decision tree regressor     0.969    0.931      2.860     5.429
# 4                      SVR     0.970    0.916      2.782     6.637
# 5            Random forest     0.972    0.952      2.607     3.823

# %%
sorted_results = results.sort_values(by=['R2_train', 'R2_test'], ascending=False)

# %%
sorted_results
# Out:
#                   ML_model  R2_train  R2_test  MSE_train  MSE_test
# 5            Random forest     0.972    0.952      2.607     3.823
# 4                      SVR     0.970    0.916      2.782     6.637
# 3  Decision tree regressor     0.969    0.931      2.860     5.429
# 1    Polynomial regression     0.899    0.862      9.325    10.857
# 0        Linear regression     0.802    0.771     18.277    18.101
# 2         Lasso regression     0.802    0.771     18.277    18.102

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Setting style
sns.set(style="whitegrid")

# Plotting
plt.figure(figsize=(8, 6))

# Create a bar plot
sns.barplot(x='ML_model', y='value', hue='Type', palette='winter' ,data=pd.melt(results, id_vars=['ML_model'], value_vars=['R2_train', 'R2_test'], value_name='value', var_name='Type'))

# Adding labels
plt.xlabel('Machine Learning Models')
plt.ylabel('R2 Scores')
plt.title('Train and Test R2 scores of ML Models')

# Show plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
best_model = rf.fit(X_train, y_train)

# %% [raw]
# We can see that Random Forest is the best algorithm for this Regression problem. SO we can save the model for future use.

# %%
import pickle

# Best model is stored in variable `best_model`

# Save model to a .pkl file
with open('best_model.pkl', 'wb') as file:
    pickle.dump(best_model, file)

print("Model saved successfully as best_model.pkl")
# Out:
# Model saved successfully as best_model.pkl
